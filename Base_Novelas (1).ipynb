# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84513000-a5d5-495a-ab1d-b69327326b82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84513000-a5d5-495a-ab1d-b69327326b82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Base Novelas.xlsx')
df.head()
# Out:
#          Unnamed: 0           Unnamed: 1  Unnamed: 2        Unnamed: 3  \
# 0               NaN                  NaN         NaN               NaN
# 1  Rótulos de Linha  Média de Audiência2         NaN  Rótulos de Linha
# 2              1972                27.97         NaN     Ivani Ribeiro
# 3              1973                27.06         NaN     Gonzaga Blota
# 4              1975            37.163333         NaN    Herval Rossano
#
#             Unnamed: 4
# 0                  NaN
# 1  Média de Audiência2
# 2              44.1175
# 3                40.02
# 4                48.74

# %%
df.shape
df.columns
df.dtypes
df.isnull().sum()
df.nunique()
df.describe()
# Out:
#        Unnamed: 2
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df.head()
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df = pd.read_excel('Base Novelas.xlsx', header=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11866/1752454458.py in <cell line: 0>()
# ----> 1 df = pd.read_excel('Base Novelas.xlsx', header=1)
#       2 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df = pd.read_excel('Base Novelas.xlsx', header=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11866/1445456443.py in <cell line: 0>()
# ----> 1 df = pd.read_excel('Base_Novelas.xlsx', header=1)
#       2 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df = pd.read_excel('/content/Projeto_Final-_Ada/Base_Novelas.xlsx', header=1)
df.head()
# Out:
#          Unnamed: 0           Unnamed: 1  Unnamed: 2        Unnamed: 3  \
# 0  Rótulos de Linha  Média de Audiência2         NaN  Rótulos de Linha
# 1              1972                27.97         NaN     Ivani Ribeiro
# 2              1973                27.06         NaN     Gonzaga Blota
# 3              1975            37.163333         NaN    Herval Rossano
# 4              1976                39.43         NaN     Roberto Talma
#
#             Unnamed: 4
# 0  Média de Audiência2
# 1              44.1175
# 2                40.02
# 3                48.74
# 4                38.53

# %%
df.head()
# Out:
#          Unnamed: 0           Unnamed: 1  Unnamed: 2        Unnamed: 3  \
# 0  Rótulos de Linha  Média de Audiência2         NaN  Rótulos de Linha
# 1              1972                27.97         NaN     Ivani Ribeiro
# 2              1973                27.06         NaN     Gonzaga Blota
# 3              1975            37.163333         NaN    Herval Rossano
# 4              1976                39.43         NaN     Roberto Talma
#
#             Unnamed: 4
# 0  Média de Audiência2
# 1              44.1175
# 2                40.02
# 3                48.74
# 4                38.53

# %%
df = pd.read_excel('/content/Projeto_Final-_Ada/Base_Novelas.xlsx', skiprows=1, header=0)

# pegar só as 2 primeiras colunas (que agora são 'Rótulos de Linha' e 'Média de Audiência2')
df1 = df[['Rótulos de Linha', 'Média de Audiência2']]

# renomear colunas
df1.columns = ['Ano', 'Audiencia']

df1.head()
# Out:
#                 Ano            Audiencia
# 1  Rótulos de Linha  Média de Audiência2
# 2              1972                27.97
# 3              1973                27.06
# 4              1975            37.163333
# 5              1976                39.43

# %%
df1.dtypes
# Out:
# Ano          object
# Audiencia    object
# dtype: object

# %%
df1['Ano'] = pd.to_numeric(df1['Ano'], errors='coerce')
df1['Audiencia'] = pd.to_numeric(df1['Audiencia'], errors='coerce')

# %%
df1.dtypes
# Out:
# Ano          float64
# Audiencia    float64
# dtype: object

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# Ano          0
# Audiencia    0
# dtype: int64
